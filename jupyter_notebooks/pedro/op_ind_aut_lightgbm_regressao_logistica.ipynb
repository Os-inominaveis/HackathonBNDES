# %% [markdown]
# # Import das bibliotecas
# Importação das bibliotecas utilizadas nesse notebook.

# %%
#Para operações com dataframes:
import pandas as pd

#Importando a biblioteca para acessar APIs 
import requests
import os

#Para formatar datas:
from datetime import datetime, timedelta

#Visualizações:
import matplotlib.pyplot as plt
import seaborn as sns

#Criação dos subgrupos para cross validation:
from sklearn.model_selection import train_test_split

#Métricas de avaliação do LightGBM e Feature Importance:
import sklearn.metrics
from sklearn.metrics import classification_report
import sklearn.metrics as metrics

#Importar o modelo de ML LightGBM:
import lightgbm as lgb

#Para hipertunagem de parâmetros:
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, cross_val_score

#Importar regressão logística do Sklearn:
from sklearn.linear_model import LogisticRegression

#Para verificar se modelo Logístico está overfitando:
from sklearn.metrics import plot_roc_curve

#Importar curva ROC AUC do Yellowbrick:
from yellowbrick.classifier import ROCAUC

#Para construção da matriz de confusão e métricas de avaliação da regressão logística:
from sklearn.metrics import confusion_matrix, plot_confusion_matrix

#Otimização de threshold da regressão logística:
from yellowbrick.classifier import DiscriminationThreshold
from yellowbrick.datasets import load_spam

# settings to display all columns
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Import dos dados
# Importação do dataset de Operações Indiretas Automáticas obtido da página do BNDES: https://dadosabertos.bndes.gov.br/dataset/operacoes-financiamento/resource/9534f677-9525-4bf8-a3aa-fd5d3e152a93
#
# Link do CSV: https://dadosabertos.bndes.gov.br/dataset/0f335c85-92a8-4343-9423-f073fb40774e/resource/9534f677-9525-4bf8-a3aa-fd5d3e152a93/download/operacoes-financiamento-operacoes-indiretas-automaticas.csv

# %%
df = pd.read_csv('operacoes-financiamento-operacoes-indiretas-automaticas.csv', sep=';')

# %%
df.head()
# Out:
#                                             cliente            cpf_cnpj   uf  \
# 0                     BANCO COOPERATIVO SICOOB S.A.  **.*38.232/0001-**   SP
# 1  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL  **.*16.560/0001-**   RS
# 2  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL  **.*16.560/0001-**   RS
# 3  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL  **.*16.560/0001-**   RS
# 4  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL  **.*16.560/0001-**   RS
#
#       municipio  municipio_codigo data_da_contratacao  \
# 0    PEDREGULHO           3537008          2002-01-02
# 1  TRES DE MAIO           4321808          2002-01-02
# 2       ERECHIM           4307005          2002-01-02
# 3       ERECHIM           4307005          2002-01-02
# 4       HUMAITA           4309704          2002-01-02
#
#    valor_da_operacao_em_reais valor_desembolsado_reais  \
# 0                       16000                  16000,0
# 1                        8047                   8047,0
# 2                        8104                   8104,0
# 3                        6304                   6304,0
# 4                       15000                  15000,0
#
#                     fonte_de_recurso_desembolsos custo_financeiro juros  \
# 0                      RECURSOS LIVRES - TESOURO        TAXA FIXA  8,75
# 1  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS        TAXA FIXA   4,0
# 2  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS        TAXA FIXA   4,0
# 3  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS        TAXA FIXA   4,0
# 4  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS        TAXA FIXA   4,0
#
#    prazo_carencia_meses  prazo_amortizacao_meses modalidade_de_apoio  \
# 0                    24                       36        REEMBOLSÁVEL
# 1                     0                       60        REEMBOLSÁVEL
# 2                    12                       48        REEMBOLSÁVEL
# 3                    12                       48        REEMBOLSÁVEL
# 4                     0                       60        REEMBOLSÁVEL
#
#   forma_de_apoio           produto instrumento_financeiro inovacao  \
# 0       INDIRETA  BNDES AUTOMÁTICO                 OUTROS      NÃO
# 1       INDIRETA  BNDES AUTOMÁTICO    PRONAF INVESTIMENTO      NÃO
# 2       INDIRETA  BNDES AUTOMÁTICO    PRONAF INVESTIMENTO      NÃO
# 3       INDIRETA  BNDES AUTOMÁTICO    PRONAF INVESTIMENTO      NÃO
# 4       INDIRETA  BNDES AUTOMÁTICO    PRONAF INVESTIMENTO      NÃO
#
#                       area_operacional            setor_cnae  \
# 0  AREA DE OPERACOES E CANAIS DIGITAIS  AGROPECUÁRIA E PESCA
# 1  AREA DE OPERACOES E CANAIS DIGITAIS  AGROPECUÁRIA E PESCA
# 2  AREA DE OPERACOES E CANAIS DIGITAIS  AGROPECUÁRIA E PESCA
# 3  AREA DE OPERACOES E CANAIS DIGITAIS  AGROPECUÁRIA E PESCA
# 4  AREA DE OPERACOES E CANAIS DIGITAIS  AGROPECUÁRIA E PESCA
#
#   subsetor_cnae_agrupado subsetor_cnae_codigo  \
# 0           Agropecuária             A0119900
# 1           Agropecuária             A0100000
# 2           Agropecuária             A0100000
# 3           Agropecuária             A0100000
# 4           Agropecuária             A0100000
#
#                                   subsetor_cnae_nome   setor_bndes  \
# 0  CULT PLANTAS LAVOURA TEMPORARIA NAO ESPECIFICA...  AGROPECUÁRIA
# 1      AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
# 2      AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
# 3      AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
# 4      AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
#
#   subsetor_bndes porte_do_cliente natureza_do_cliente  \
# 0   AGROPECUÁRIA            MICRO             PRIVADA
# 1   AGROPECUÁRIA            MICRO             PRIVADA
# 2   AGROPECUÁRIA            MICRO             PRIVADA
# 3   AGROPECUÁRIA            MICRO             PRIVADA
# 4   AGROPECUÁRIA            MICRO             PRIVADA
#
#                  instituicao_financeira_credenciada cnpj_do_agente_financeiro  \
# 0                     BANCO COOPERATIVO SICOOB S.A.        02.038.232.0001-64
# 1  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL        92.816.560.0001-37
# 2  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL        92.816.560.0001-37
# 3  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL        92.816.560.0001-37
# 4  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL        92.816.560.0001-37
#
#   situacao_da_operacao
# 0            LIQUIDADA
# 1            LIQUIDADA
# 2            LIQUIDADA
# 3            LIQUIDADA
# 4            LIQUIDADA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2083363 entries, 0 to 2083362
# Data columns (total 30 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   cliente                             object
#  1   cpf_cnpj                            object
#  2   uf                                  object
#  3   municipio                           object
#  4   municipio_codigo                    int64
#  5   data_da_contratacao                 object
#  6   valor_da_operacao_em_reais          int64
#  7   valor_desembolsado_reais            object
#  8   fonte_de_recurso_desembolsos        object
#  9   custo_financeiro                    object
#  10  juros                               object
#  11  prazo_carencia_meses                int64
#  12  prazo_amortizacao_meses             int64
#  13  modalidade_de_apoio                 object
#  14  forma_de_apoio                      object
#  15  produto                             object
#  16  instrumento_financeiro              object
#  17  inovacao                            object
#  18  area_operacional                    object
#  19  setor_cnae                          object
#  20  subsetor_cnae_agrupado              object
#  21  subsetor_cnae_codigo                object
#  22  subsetor_cnae_nome                  object
#  23  setor_bndes                         object
#  24  subsetor_bndes                      object
#  25  porte_do_cliente                    object
#  26  natureza_do_cliente                 object
#  27  instituicao_financeira_credenciada  object
#  28  cnpj_do_agente_financeiro           object
#  29  situacao_da_operacao                object
# dtypes: int64(4), object(26)
# memory usage: 476.8+ MB

# %% [markdown]
# # Tratamento dos dados
# Essa etapa compreendeu o tratamento dos dados para o execução da etapa de Feature Selection e Regressão Logística.

# %% [markdown]
# ## Criando colunas de tempo e investimentos "inadimplentes"/"liquidados".
# Notou-se que haviam colunas com datas de contratação, prazos de amortização e prazos de carência. Essas colunas poderiam ser somadas para obter-se uma data prevista de liquidez do investimento e a partir disso, criar um indicar se o projeto foi ou não liquidado no prazo estimado (dadas as restrições do próprio dataset, já que não foi fornecido a data de liquidez de investimentos já liquidados).

# %%
#Transformando a série que está em object para timestamp
df['data_da_contratacao'] = pd.to_datetime(df['data_da_contratacao'])

# %%
#Formatando as colunas de meses para realizar a soma na data_prevista
df['prazo_carencia_meses'] = df['prazo_carencia_meses'].astype('timedelta64[M]')
df['prazo_amortizacao_meses'] = df['prazo_amortizacao_meses'].astype('timedelta64[M]')

# %%
#Criando uma coluna de previsão do último pagamento
df['data_prevista'] = df['data_da_contratacao'] + df['prazo_carencia_meses'] + df['prazo_amortizacao_meses']
df['data_prevista']
# Out:
# 0         2007-01-02 05:06:00
# 1         2007-01-02 05:06:00
# 2         2007-01-02 05:06:00
# 3         2007-01-02 05:06:00
# 4         2007-01-02 05:06:00
#                   ...
# 2083358   2026-05-31 05:06:00
# 2083359   2026-05-31 05:06:00
# 2083360   2026-05-31 05:06:00
# 2083361   2025-05-30 23:16:48
# 2083362   2026-05-31 05:06:00
# Name: data_prevista, Length: 2083363, dtype: datetime64[ns]

# %%
df['data_prevista'][0]
# Out:
# Timestamp('2007-01-02 05:06:00')

# %%
#Encontrando o tempo:
datetime.now()
# Out:
# datetime.datetime(2021, 8, 29, 20, 58, 37, 166153)

# %%
df['data_futuro_bool'] = df['data_prevista'] > datetime.now()

# %%
#Criando a função:
def Comparador(row):
    if (row['situacao_da_operacao'] == 'LIQUIDADA' and row['data_futuro_bool'] == 1):
        return 'Bom'
    elif (row['situacao_da_operacao'] == 'ATIVA' and row['data_futuro_bool'] == 0):
        return 'Mal'
    else:
        return 'dropa'

# %%
#Aplicamos a função:
df['bom_investimento'] = df.apply(Comparador, axis=1)

# %%
#Temos três tipos de classificações:
df['bom_investimento'].value_counts()
# Out:
# dropa_bagulho    1997223
# Bom                50241
# Mal                35899
# Name: bom_investimento, dtype: int64

# %%
#Filtrando somente os clientes classificados como Bom e Mal:
df = df[~(df['bom_investimento']=='dropa')]

# %%
#Checando se só tem Bom e Mal cliente:
df['bom_investimento'].value_counts()
# Out:
# Bom    50241
# Mal    35899
# Name: bom_investimento, dtype: int64

# %% [markdown]
# ## Dropando colunas sem uso para ML
# Algumas colunas não teriam necessidade para nossa análise.

# %%
df = df.drop(columns=['cpf_cnpj', 'cnpj_do_agente_financeiro', 'situacao_da_operacao', 'data_futuro_bool', 'municipio', 'cliente'], errors='ignore')

# %%
df.head()
# Out:
#      uf  municipio_codigo data_da_contratacao  valor_da_operacao_em_reais  \
# 36   RS           4321808          2002-01-02                        2303
# 37   RS           4321808          2002-01-02                        2303
# 38   RS           4321808          2002-01-02                        2373
# 48   RS           4321329          2002-01-02                        2400
# 49   RS           4321329          2002-01-02                        1700
#
#    valor_desembolsado_reais                   fonte_de_recurso_desembolsos  \
# 36                   2303,0  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS
# 37                   2303,0  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS
# 38                   2373,0  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS
# 48                   2400,0  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS
# 49                   1700,0  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS
#
#    custo_financeiro juros prazo_carencia_meses prazo_amortizacao_meses  \
# 36        TAXA FIXA   4,0               0 days      1460 days 23:16:48
# 37        TAXA FIXA   4,0               0 days      1460 days 23:16:48
# 38        TAXA FIXA   4,0               0 days      1460 days 23:16:48
# 48        TAXA FIXA   4,0               0 days      1095 days 17:27:36
# 49        TAXA FIXA   4,0               0 days      1095 days 17:27:36
#
#    modalidade_de_apoio forma_de_apoio           produto  \
# 36        REEMBOLSÁVEL       INDIRETA  BNDES AUTOMÁTICO
# 37        REEMBOLSÁVEL       INDIRETA  BNDES AUTOMÁTICO
# 38        REEMBOLSÁVEL       INDIRETA  BNDES AUTOMÁTICO
# 48        REEMBOLSÁVEL       INDIRETA  BNDES AUTOMÁTICO
# 49        REEMBOLSÁVEL       INDIRETA  BNDES AUTOMÁTICO
#
#    instrumento_financeiro inovacao                     area_operacional  \
# 36    PRONAF INVESTIMENTO      NÃO  AREA DE OPERACOES E CANAIS DIGITAIS
# 37    PRONAF INVESTIMENTO      NÃO  AREA DE OPERACOES E CANAIS DIGITAIS
# 38    PRONAF INVESTIMENTO      NÃO  AREA DE OPERACOES E CANAIS DIGITAIS
# 48    PRONAF INVESTIMENTO      NÃO  AREA DE OPERACOES E CANAIS DIGITAIS
# 49    PRONAF INVESTIMENTO      NÃO  AREA DE OPERACOES E CANAIS DIGITAIS
#
#               setor_cnae subsetor_cnae_agrupado subsetor_cnae_codigo  \
# 36  AGROPECUÁRIA E PESCA           Agropecuária             A0100000
# 37  AGROPECUÁRIA E PESCA           Agropecuária             A0100000
# 38  AGROPECUÁRIA E PESCA           Agropecuária             A0100000
# 48  AGROPECUÁRIA E PESCA           Agropecuária             A0100000
# 49  AGROPECUÁRIA E PESCA           Agropecuária             A0100000
#
#                                subsetor_cnae_nome   setor_bndes  \
# 36  AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
# 37  AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
# 38  AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
# 48  AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
# 49  AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
#
#    subsetor_bndes porte_do_cliente natureza_do_cliente  \
# 36   AGROPECUÁRIA            MICRO             PRIVADA
# 37   AGROPECUÁRIA            MICRO             PRIVADA
# 38   AGROPECUÁRIA            MICRO             PRIVADA
# 48   AGROPECUÁRIA            MICRO             PRIVADA
# 49   AGROPECUÁRIA            MICRO             PRIVADA
#
#                   instituicao_financeira_credenciada       data_prevista  \
# 36  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL 2006-01-01 23:16:48
# 37  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL 2006-01-01 23:16:48
# 38  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL 2006-01-01 23:16:48
# 48  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL 2005-01-01 17:27:36
# 49  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL 2005-01-01 17:27:36
#
#    bom_investimento
# 36              Mal
# 37              Mal
# 38              Mal
# 48              Mal
# 49              Mal

# %%
df.head()
# Out:
#      uf  municipio_codigo data_da_contratacao  valor_da_operacao_em_reais  \
# 36   RS           4321808          2002-01-02                        2303
# 37   RS           4321808          2002-01-02                        2303
# 38   RS           4321808          2002-01-02                        2373
# 48   RS           4321329          2002-01-02                        2400
# 49   RS           4321329          2002-01-02                        1700
#
#    valor_desembolsado_reais                   fonte_de_recurso_desembolsos  \
# 36                   2303,0  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS
# 37                   2303,0  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS
# 38                   2373,0  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS
# 48                   2400,0  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS
# 49                   1700,0  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS
#
#    custo_financeiro juros prazo_carencia_meses prazo_amortizacao_meses  \
# 36        TAXA FIXA   4,0               0 days      1460 days 23:16:48
# 37        TAXA FIXA   4,0               0 days      1460 days 23:16:48
# 38        TAXA FIXA   4,0               0 days      1460 days 23:16:48
# 48        TAXA FIXA   4,0               0 days      1095 days 17:27:36
# 49        TAXA FIXA   4,0               0 days      1095 days 17:27:36
#
#    modalidade_de_apoio forma_de_apoio           produto  \
# 36        REEMBOLSÁVEL       INDIRETA  BNDES AUTOMÁTICO
# 37        REEMBOLSÁVEL       INDIRETA  BNDES AUTOMÁTICO
# 38        REEMBOLSÁVEL       INDIRETA  BNDES AUTOMÁTICO
# 48        REEMBOLSÁVEL       INDIRETA  BNDES AUTOMÁTICO
# 49        REEMBOLSÁVEL       INDIRETA  BNDES AUTOMÁTICO
#
#    instrumento_financeiro inovacao                     area_operacional  \
# 36    PRONAF INVESTIMENTO      NÃO  AREA DE OPERACOES E CANAIS DIGITAIS
# 37    PRONAF INVESTIMENTO      NÃO  AREA DE OPERACOES E CANAIS DIGITAIS
# 38    PRONAF INVESTIMENTO      NÃO  AREA DE OPERACOES E CANAIS DIGITAIS
# 48    PRONAF INVESTIMENTO      NÃO  AREA DE OPERACOES E CANAIS DIGITAIS
# 49    PRONAF INVESTIMENTO      NÃO  AREA DE OPERACOES E CANAIS DIGITAIS
#
#               setor_cnae subsetor_cnae_agrupado subsetor_cnae_codigo  \
# 36  AGROPECUÁRIA E PESCA           Agropecuária             A0100000
# 37  AGROPECUÁRIA E PESCA           Agropecuária             A0100000
# 38  AGROPECUÁRIA E PESCA           Agropecuária             A0100000
# 48  AGROPECUÁRIA E PESCA           Agropecuária             A0100000
# 49  AGROPECUÁRIA E PESCA           Agropecuária             A0100000
#
#                                subsetor_cnae_nome   setor_bndes  \
# 36  AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
# 37  AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
# 38  AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
# 48  AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
# 49  AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
#
#    subsetor_bndes porte_do_cliente natureza_do_cliente  \
# 36   AGROPECUÁRIA            MICRO             PRIVADA
# 37   AGROPECUÁRIA            MICRO             PRIVADA
# 38   AGROPECUÁRIA            MICRO             PRIVADA
# 48   AGROPECUÁRIA            MICRO             PRIVADA
# 49   AGROPECUÁRIA            MICRO             PRIVADA
#
#                   instituicao_financeira_credenciada       data_prevista  \
# 36  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL 2006-01-01 23:16:48
# 37  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL 2006-01-01 23:16:48
# 38  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL 2006-01-01 23:16:48
# 48  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL 2005-01-01 17:27:36
# 49  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL 2005-01-01 17:27:36
#
#    bom_investimento
# 36              Mal
# 37              Mal
# 38              Mal
# 48              Mal
# 49              Mal

# %% [markdown]
# ## Remover espaços do UF
# As unidades federais estavam com espaçamentos antes do primeiro caracter - o mesmo foi retirado.

# %%
df['uf'].value_counts().index
# Out:
# Index([' RS', ' SP', ' PR', ' MG', ' SC', ' RJ', ' GO', ' MT', ' BA', ' ES',
#        ' MS', ' PA', ' PE', ' MA', ' CE', ' TO', ' DF', ' RO', ' PB', ' PI',
#        ' RN', ' AM', ' AL', ' SE', ' AC', ' AP', ' RR'],
#       dtype='object')

# %%
df['uf'] = df['uf'].apply(lambda x: x.strip())

# %%
df['uf'].value_counts().index
# Out:
# Index(['RS', 'SP', 'PR', 'MG', 'SC', 'RJ', 'GO', 'MT', 'BA', 'ES', 'MS', 'PA',
#        'PE', 'MA', 'CE', 'TO', 'DF', 'RO', 'PB', 'PI', 'RN', 'AM', 'AL', 'SE',
#        'AC', 'AP', 'RR'],
#       dtype='object')

# %% [markdown]
# ## Transformando 'Juros' de Object para Float
# Juros estavam com casas decimais expressas com vírgula, transformamos para ponto.

# %%
df['juros'] = df['juros'].str.replace(',', '.')
df['juros'] = df['juros'].astype('float')

# %% [markdown]
# ## Transformando Objects em Category
# Transformamos colunas do tipo object em tipo category, já que o LightGBMClassifier só aceitaria esses dados no formato category.

# %%
df_categorizado = df.copy(deep=True)

# %%
categorical_feats = df_categorizado.select_dtypes(include=['object', 'category']).columns.to_list()
for c in categorical_feats:
    df_categorizado[c] = df_categorizado[c].astype('category')

# %%
# Método do Sarit
#for c in X.columns:
#col_type = X[c].dtype
#if col_type == 'object' or col_type.name == 'category':
#X[c] = X[c].astype('category')

# %% [markdown]
# ## Preparação para o modelo
# Preparou-se os dados para o hold out do LightGBMClassifier, formatando-se tipos de dados e substituindo-se alguns caracteres.

# %%
#Transformando as vírgulas em pontos na coluna de 'juros':
df_categorizado['valor_desembolsado_reais'] = df_categorizado['valor_desembolsado_reais'].str.replace(',', '.')

#Transformando a coluna 'juros' em float
df_categorizado['valor_desembolsado_reais'] = df_categorizado['valor_desembolsado_reais'].astype('float')

# %%
#Transformando o código do município em tipo category:
df_categorizado['município_codigo'] = df_categorizado['municipio_codigo'].astype('category')

# %%
#df_categorizado.columns

# %%
#Dropando colunas que geram multicolinearidade
df_categorizado = df_categorizado.drop(labels=['data_da_contratacao', 'prazo_carencia_meses',
                                               'prazo_amortizacao_meses', 'data_prevista', 'subsetor_cnae_agrupado', 'subsetor_cnae_codigo'], axis=1, errors='ignore')

# %% [markdown]
# ## Nulos
# Verificada a presença de nulos, os quais eram muito poucos.

# %%
sns.set({'figure.figsize':(20,20)})
sns.heatmap(df.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Hold out
# A fim de evitar o overfitting dos dados (e perda de abrangência do modelo), foi realizada a separação dos dados em grupos de treino, teste e validação.

# %%
y1 = df_categorizado['bom_investimento'].values
X1 = df_categorizado.drop(columns = 'bom_investimento')

# %%
# divide 80% treino_validação e 20% teste
train_val_x, test_x, train_val_y, test_y = train_test_split(X1, y1, test_size=0.2, random_state=101, stratify=y1)
print('Treino & Validação:', train_val_x.shape)
print('Teste:', test_x.shape)
# Out:
# Treino & Validação: (68912, 21)
# Teste: (17228, 21)

# %%
# divide 80% treino_validação e 20% teste
train_x, val_x, train_y, val_y = train_test_split(train_val_x, train_val_y, test_size=0.2, random_state=101, stratify=train_val_y)
print('Treino:', train_x.shape)
print('Validação:', val_x.shape)
# Out:
# Treino: (55129, 21)
# Validação: (13783, 21)

# %% [markdown]
# # Feature selection com LightGBMClassifier
# Como existiam muitas features / características no dataset, a fim de simplificar o modelo de regressão logística, foi estudada uma maneira de selecionar as features que teriam maior relevância na métrica criada de investimentos "inadimplentes" ou "liquidados".

# %% [markdown]
# ## Modelagem com LightGBMClassifier
# Foi realizada a modelagem com os dados de treino e avaliado com os dados de teste, sendo escolhida a métrica da área sob a curva e F1-Score para uma análise mais balanceada.

# %%
#Instanciando o modelo LightGBM:
model = lgb.LGBMClassifier(loss_function= 'Logloss', custom_metric=['Accuracy','AUC'],eval_metric='F1')

# %%
model.fit(train_x, train_y, eval_set=(test_x, test_y), feature_name='auto', categorical_feature = 'auto', verbose=50)
# Out:
# [LightGBM] [Warning] Unknown parameter: loss_function
# [LightGBM] [Warning] Unknown parameter: custom_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# C:\Users\pfaprado\AppData\Roaming\Python\Python39\site-packages\lightgbm\basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# C:\Users\pfaprado\AppData\Roaming\Python\Python39\site-packages\lightgbm\basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [50]	valid_0's binary_logloss: 0.16739
# [100]	valid_0's binary_logloss: 0.148775
# LGBMClassifier(custom_metric=['Accuracy', 'AUC'], eval_metric='F1',
#                loss_function='Logloss')

# %%
print(model)# make predictions
# Out:
# LGBMClassifier(custom_metric=['Accuracy', 'AUC'], eval_metric='F1',
#                loss_function='Logloss')

# %%
expected_y  = test_y

# %%
pred_y = model.predict(test_x)# summarize the fit of the model

# %%
print(metrics.classification_report(expected_y, pred_y))
# Out:
#               precision    recall  f1-score   support
#
#          Bom       0.93      0.97      0.95     10048
#          Mal       0.96      0.90      0.93      7180
#
#     accuracy                           0.95     17228
#    macro avg       0.95      0.94      0.94     17228
# weighted avg       0.95      0.95      0.94     17228

# %%
print(metrics.confusion_matrix(expected_y, pred_y))
# Out:
# [[9791  257]
#  [ 687 6493]]

# %% [markdown]
# ## Feature Importance
# Realizando o feature importance através do LightGBMClassifier, conseguimos eleger um número finito de features (5) mais relevantes para uma regressão logística. Estas features seriam código do munício, subsetor CNAE, instituição financeira credenciada, taxa de juros e instrumento financeiro.

# %%
feat_imp = pd.Series(model.feature_importances_, index=X1.columns)
feat_imp.nlargest(30).plot(kind='barh', figsize=(8,6))
plt.title('Feature importance-LightGBM')
plt.show()

# %% [markdown]
# ## Interpretando o Feature Importance
# Há grande variabilidade nas categorias (código de munícipio), sendo que a primeira categoria no Pareto tem apenas 3% dos dados. Isso é um bom indicador de que os dados não sofreram overfitting com um munícipio específico e garante uma maior abrangência no modelo.

# %%
df_categorizado.municipio_codigo.value_counts()
# Out:
# 3550308    2960
# 3530607    2690
# 3106200    2143
# 3304557    1924
# 4113700    1108
#            ...
# 3509601       1
# 2114007       1
# 2405702       1
# 4125902       1
# 1301852       1
# Name: municipio_codigo, Length: 3154, dtype: int64

# %%
df_categorizado['municipio_codigo'].value_counts().values[0]/df_categorizado['municipio_codigo'].value_counts().sum()
# Out:
# 0.034362665428372415

# %% [markdown]
# # Logistic Regression
# Com as categorias definidas através do LightGBMClassifier, realizou-se o preprocessamento dos dados, como por exemplo "Dummificação" de variáveis categóricas. Afinal todas as variáveis escolhidas para a modelagem da regressão logística eram variáveis categóricas.

# %% [markdown]
# ## Dumificar variáveis categóricas
# Dummificou-se as variáveis categóricas para a modelagem da regressão logística Isso significa que para cada nível de uma variável categórica, foi criada uma coluna no dataset com um valor de 0 ou 1, dependendo se o nível da variável original é aquele sendo avaliado na coluna dumificada.

# %%
df.columns
# Out:
# Index(['uf', 'municipio_codigo', 'data_da_contratacao',
#        'valor_da_operacao_em_reais', 'valor_desembolsado_reais',
#        'fonte_de_recurso_desembolsos', 'custo_financeiro', 'juros',
#        'prazo_carencia_meses', 'prazo_amortizacao_meses',
#        'modalidade_de_apoio', 'forma_de_apoio', 'produto',
#        'instrumento_financeiro', 'inovacao', 'area_operacional', 'setor_cnae',
#        'subsetor_cnae_agrupado', 'subsetor_cnae_codigo', 'subsetor_cnae_nome',
#        'setor_bndes', 'subsetor_bndes', 'porte_do_cliente',
#        'natureza_do_cliente', 'instituicao_financeira_credenciada',
#        'data_prevista', 'bom_investimento'],
#       dtype='object')

# %%
lista_cols = ['municipio_codigo', 'subsetor_cnae_nome', 'juros', 'instituicao_financeira_credenciada', 'instrumento_financeiro']

# %%
df['bom_investimento'].replace(to_replace='Bom', value=1, inplace=True)
df['bom_investimento'].replace(to_replace='Mal', value=0, inplace=True)

# %% [markdown]
# Como selecionamos só 5 colunas, vamos dropar todas as outras que são variáveis dependentes de 'bom_investimento':

# %%
df_escolhido = df.loc[:, ['municipio_codigo', 'subsetor_cnae_nome', 'instituicao_financeira_credenciada', 'instrumento_financeiro', 'bom_investimento']]

# %%
# converting all the categorical variables into dummy variables
df_dummies = pd.get_dummies(df_escolhido, columns = ['municipio_codigo', 'subsetor_cnae_nome', 'instituicao_financeira_credenciada', 'instrumento_financeiro'])

# %%
df_dummies.shape
# Out:
# (86140, 4289)

# %%
df_dummies.columns
# Out:
# Index(['bom_investimento', 'municipio_codigo_1100015',
#        'municipio_codigo_1100023', 'municipio_codigo_1100049',
#        'municipio_codigo_1100056', 'municipio_codigo_1100064',
#        'municipio_codigo_1100072', 'municipio_codigo_1100080',
#        'municipio_codigo_1100098', 'municipio_codigo_1100106',
#        ...
#        'instrumento_financeiro_PRONAMP INVESTIMENTO',
#        'instrumento_financeiro_PROPFLORA',
#        'instrumento_financeiro_PRÓ-CDD MAÇA',
#        'instrumento_financeiro_PSI - BK - Demais Itens',
#        'instrumento_financeiro_PSI - BK - Rural',
#        'instrumento_financeiro_PSI - BK - Tecnologia Nacional',
#        'instrumento_financeiro_PSI - BK - Ônibus e Caminhão',
#        'instrumento_financeiro_PSI - Inovação',
#        'instrumento_financeiro_PSI - Inovação - BK Eficientes',
#        'instrumento_financeiro_TURISMO, COMÉRCIO E SERVIÇOS'],
#       dtype='object', length=4289)

# %% [markdown]
# ## Hold out
# A fim de evitar overfitting dos dados, separamos os mesmos em três grupos: treino, teste e validação.

# %%
y1 = df_dummies['bom_investimento'].values
X1 = df_dummies.drop(columns = 'bom_investimento')

# %%
# divide 80% treino_validação e 20% teste
train_val_x, test_x, train_val_y, test_y = train_test_split(X1, y1, test_size=0.2, random_state=101, stratify=y1)
print('Treino & Validação:', train_val_x.shape)
print('Teste:', test_x.shape)
# Out:
# Treino & Validação: (68912, 4288)
# Teste: (17228, 4288)

# %%
# divide 80% treino_validação e 20% teste
train_x, val_x, train_y, val_y = train_test_split(train_val_x, train_val_y, test_size=0.2, random_state=101, stratify=train_val_y)
print('Treino:', train_x.shape)
print('Validação:', val_x.shape)
# Out:
# Treino: (55129, 4288)
# Validação: (13783, 4288)

# %%
#Instanciando o modelo:
logistic = LogisticRegression(max_iter=1000)

# %%
#Fitar o modelo
logistic.fit(X=train_x, y=train_y)
# Out:
# LogisticRegression(max_iter=1000)

# %%
predictions = logistic.predict(test_x)
pred_y = predictions #prediction

# %%
print('Predições:', pred_y.shape)
# Out:
# Predições: (17228,)

# %%
#Métricas de avaliação
print("Prediction: ", metrics.accuracy_score(test_y, pred_y))
print("Precision: ", metrics.precision_score(test_y, pred_y))
print("Recall: ", metrics.recall_score(test_y, pred_y))
# Out:
# Prediction:  0.8747968423496634
# Precision:  0.8517428902558616
# Recall:  0.9508359872611465

# %%
#Construir a matriz de confusão:
cnf_matrix = confusion_matrix(test_y, predictions)

# %%
#Mostrar a matriz de confusão:
cnf_matrix
# Out:
# array([[5517, 1663],
#        [ 494, 9554]], dtype=int64)

# %%
plot_confusion_matrix(logistic, test_x, test_y, values_format='.0f')

# %%
plot_confusion_matrix(logistic, test_x, test_y, values_format='.3f', normalize='all')

# %% [markdown]
# # Otimização de Threshold
# Podemos otimizar o threshold, que por default é 0.5. Esses valores podem aumentar/diminuir a precisão ou recall, dependendo do objetivo de negócio (perfil mais permissivo ou perfil mais conservador na análise de investimentos). Ou ainda temos um perfil equilibrado com threshold 0,43 (F1-Score máximo).

# %%
# Instantiate the visualizer with the classification model
visualizer = ROCAUC(logistic, classes=["non-default", "default"], micro=False, per_class=True)
visualizer.fit(train_x, train_y)        # Fit the training data to the visualizer
visualizer.score(test_x, test_y)        # Evaluate the model on the test data
visualizer.show()                       # Finalize and show the figure
# Out:
# <AxesSubplot:title={'center':'ROC Curves for LogisticRegression'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %%
# Load a binary classification dataset
X1, y1 = load_spam()

# Instantiate the classification model and visualizer
model = LogisticRegression(multi_class="auto", solver="liblinear")
visualizer = DiscriminationThreshold(model)

visualizer.fit(X1, y1)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# c:\users\pfaprado\appdata\local\programs\python\python39\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# c:\users\pfaprado\appdata\local\programs\python\python39\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# c:\users\pfaprado\appdata\local\programs\python\python39\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# <AxesSubplot:title={'center':'Threshold Plot for LogisticRegression'}, xlabel='discrimination threshold', ylabel='score'>

# %% [markdown]
# # Hipertunagem de parâmetros do modelo de Regressão Logística
# Ainda foi possível realizar uma hipertunagem dos parâmetros do modelo de regressão logísitca através do grid_search, alimentado-se ao espaço amostral valores de C e retornando-se o melhor estimador, nesse caso C = 2.

# %%
model = LogisticRegression()

# %%
search_space = [{
    'C': [0.1,0.2,0.5, 0.6, 0.8, 0.9, 1, 2, 4, 6]
}]

# %%
grid_search = GridSearchCV(model, 
                           search_space, 
                           cv=KFold(3), 
                           scoring='roc_auc', 
                           n_jobs=-1, 
                           verbose=True)

# %%
grid_search.fit(train_x, train_y)

# %%
grid_search.best_estimator_

# %% [markdown]
# O best estimator retornado é C=2.

# %% [markdown]
# # Simulação com uma entrada
# Com o modelo criado e utilizando threshold padrão de 0.5, fizemos uma simulação para verificar o funcionamento, retornado a previsão observada.

# %%
predictions = logistic.predict(val_x.head(1))
pred_val_y = predictions #prediction

# %% [markdown]
# Valor predito:

# %%
pred_val_y[0]
# Out:
# 1

# %% [markdown]
# Valor real:

# %%
val_y[1]
# Out:
# 1

# %% [markdown]
# Dataframe real:

# %%
val_x.head(1)
# Out:
#          municipio_codigo_1100015  municipio_codigo_1100023  \
# 2057437                         0                         0
#
#          municipio_codigo_1100049  municipio_codigo_1100056  \
# 2057437                         0                         0
#
#          municipio_codigo_1100064  municipio_codigo_1100072  \
# 2057437                         0                         0
#
#          municipio_codigo_1100080  municipio_codigo_1100098  \
# 2057437                         0                         0
#
#          municipio_codigo_1100106  municipio_codigo_1100114  \
# 2057437                         0                         0
#
#          municipio_codigo_1100122  municipio_codigo_1100130  \
# 2057437                         0                         0
#
#          municipio_codigo_1100148  municipio_codigo_1100155  \
# 2057437                         0                         0
#
#          municipio_codigo_1100189  municipio_codigo_1100205  \
# 2057437                         0                         0
#
#          municipio_codigo_1100254  municipio_codigo_1100288  \
# 2057437                         0                         0
#
#          municipio_codigo_1100304  municipio_codigo_1100320  \
# 2057437                         0                         0
#
#          municipio_codigo_1100338  municipio_codigo_1100379  \
# 2057437                         0                         0
#
#          municipio_codigo_1100452  municipio_codigo_1100809  \
# 2057437                         0                         0
#
#          municipio_codigo_1100924  municipio_codigo_1100940  \
# 2057437                         0                         0
#
#          municipio_codigo_1101104  municipio_codigo_1101203  \
# 2057437                         0                         0
#
#          municipio_codigo_1101302  municipio_codigo_1101468  \
# 2057437                         0                         0
#
#          municipio_codigo_1101484  municipio_codigo_1200104  \
# 2057437                         0                         0
#
#          municipio_codigo_1200203  municipio_codigo_1200302  \
# 2057437                         0                         0
#
#          municipio_codigo_1200344  municipio_codigo_1200401  \
# 2057437                         0                         0
#
#          municipio_codigo_1200450  municipio_codigo_1200500  \
# 2057437                         0                         0
#
#          municipio_codigo_1200609  municipio_codigo_1300086  \
# 2057437                         0                         0
#
#          municipio_codigo_1301209  municipio_codigo_1301308  \
# 2057437                         0                         0
#
#          municipio_codigo_1301704  municipio_codigo_1301852  \
# 2057437                         0                         0
#
#          municipio_codigo_1301902  municipio_codigo_1302405  \
# 2057437                         0                         0
#
#          municipio_codigo_1302504  municipio_codigo_1302603  \
# 2057437                         0                         0
#
#          municipio_codigo_1302702  municipio_codigo_1302900  \
# 2057437                         0                         0
#
#          municipio_codigo_1303809  municipio_codigo_1400100  \
# 2057437                         0                         0
#
#          municipio_codigo_1400209  municipio_codigo_1400472  \
# 2057437                         0                         0
#
#          municipio_codigo_1500107  municipio_codigo_1500206  \
# 2057437                         0                         0
#
#          municipio_codigo_1500305  municipio_codigo_1500503  \
# 2057437                         0                         0
#
#          municipio_codigo_1500602  municipio_codigo_1500800  \
# 2057437                         0                         0
#
#          municipio_codigo_1500859  municipio_codigo_1501303  \
# 2057437                         0                         0
#
#          municipio_codigo_1501402  municipio_codigo_1501501  \
# 2057437                         0                         0
#
#          municipio_codigo_1501709  municipio_codigo_1501782  \
# 2057437                         0                         0
#
#          municipio_codigo_1502152  municipio_codigo_1502202  \
# 2057437                         0                         0
#
#          municipio_codigo_1502301  municipio_codigo_1502400  \
# 2057437                         0                         0
#
#          municipio_codigo_1502707  municipio_codigo_1502905  \
# 2057437                         0                         0
#
#          municipio_codigo_1502939  municipio_codigo_1503200  \
# 2057437                         0                         0
#
#          municipio_codigo_1503309  municipio_codigo_1503457  \
# 2057437                         0                         0
#
#          municipio_codigo_1503606  municipio_codigo_1503705  \
# 2057437                         0                         0
#
#          municipio_codigo_1503903  municipio_codigo_1504059  \
# 2057437                         0                         0
#
#          municipio_codigo_1504208  municipio_codigo_1504422  \
# 2057437                         0                         0
#
#          municipio_codigo_1504703  municipio_codigo_1504901  \
# 2057437                         0                         0
#
#          municipio_codigo_1504976  municipio_codigo_1505031  \
# 2057437                         0                         0
#
#          municipio_codigo_1505064  municipio_codigo_1505304  \
# 2057437                         0                         0
#
#          municipio_codigo_1505437  municipio_codigo_1505486  \
# 2057437                         0                         0
#
#          municipio_codigo_1505502  municipio_codigo_1505536  \
# 2057437                         0                         0
#
#          municipio_codigo_1505635  municipio_codigo_1506138  \
# 2057437                         0                         0
#
#          municipio_codigo_1506161  municipio_codigo_1506187  \
# 2057437                         0                         0
#
#          municipio_codigo_1506500  municipio_codigo_1506583  \
# 2057437                         0                         0
#
#          municipio_codigo_1506609  municipio_codigo_1506708  \
# 2057437                         0                         0
#
#          municipio_codigo_1506807  municipio_codigo_1507003  \
# 2057437                         0                         0
#
#          municipio_codigo_1507755  municipio_codigo_1507953  \
# 2057437                         0                         0
#
#          municipio_codigo_1507979  municipio_codigo_1508001  \
# 2057437                         0                         0
#
#          municipio_codigo_1508084  municipio_codigo_1508100  \
# 2057437                         0                         0
#
#          municipio_codigo_1508126  municipio_codigo_1508407  \
# 2057437                         0                         0
#
#          municipio_codigo_1600279  municipio_codigo_1600303  \
# 2057437                         0                         0
#
#          municipio_codigo_1600535  municipio_codigo_1600600  \
# 2057437                         0                         0
#
#          municipio_codigo_1600808  municipio_codigo_1700400  \
# 2057437                         0                         0
#
#          municipio_codigo_1700707  municipio_codigo_1701101  \
# 2057437                         0                         0
#
#          municipio_codigo_1702000  municipio_codigo_1702109  \
# 2057437                         0                         0
#
#          municipio_codigo_1702208  municipio_codigo_1702554  \
# 2057437                         0                         0
#
#          municipio_codigo_1703008  municipio_codigo_1703057  \
# 2057437                         0                         0
#
#          municipio_codigo_1703842  municipio_codigo_1703909  \
# 2057437                         0                         0
#
#          municipio_codigo_1705102  municipio_codigo_1705508  \
# 2057437                         0                         0
#
#          municipio_codigo_1706001  municipio_codigo_1706100  \
# 2057437                         0                         0
#
#          municipio_codigo_1706506  municipio_codigo_1707009  \
# 2057437                         0                         0
#
#          municipio_codigo_1707652  municipio_codigo_1708205  \
# 2057437                         0                         0
#
#          municipio_codigo_1709302  municipio_codigo_1709500  \
# 2057437                         0                         0
#
#          municipio_codigo_1711902  municipio_codigo_1712504  \
# 2057437                         0                         0
#
#          municipio_codigo_1712702  municipio_codigo_1713205  \
# 2057437                         0                         0
#
#          municipio_codigo_1713601  municipio_codigo_1714880  \
# 2057437                         0                         0
#
#          municipio_codigo_1715002  municipio_codigo_1715259  \
# 2057437                         0                         0
#
#          municipio_codigo_1715705  municipio_codigo_1715754  \
# 2057437                         0                         0
#
#          municipio_codigo_1716109  municipio_codigo_1716505  \
# 2057437                         0                         0
#
#          municipio_codigo_1716604  municipio_codigo_1716703  \
# 2057437                         0                         0
#
#          municipio_codigo_1717206  municipio_codigo_1717800  \
# 2057437                         0                         0
#
#          municipio_codigo_1718204  municipio_codigo_1718402  \
# 2057437                         0                         0
#
#          municipio_codigo_1720903  municipio_codigo_1720978  \
# 2057437                         0                         0
#
#          municipio_codigo_1721000  municipio_codigo_1721208  \
# 2057437                         0                         0
#
#          municipio_codigo_1722081  municipio_codigo_1722107  \
# 2057437                         0                         0
#
#          municipio_codigo_2100055  municipio_codigo_2100477  \
# 2057437                         0                         0
#
#          municipio_codigo_2100501  municipio_codigo_2100808  \
# 2057437                         0                         0
#
#          municipio_codigo_2100956  municipio_codigo_2101202  \
# 2057437                         0                         0
#
#          municipio_codigo_2101251  municipio_codigo_2101400  \
# 2057437                         0                         0
#
#          municipio_codigo_2101608  municipio_codigo_2101707  \
# 2057437                         0                         0
#
#          municipio_codigo_2101772  municipio_codigo_2101905  \
# 2057437                         0                         0
#
#          municipio_codigo_2102309  municipio_codigo_2102754  \
# 2057437                         0                         0
#
#          municipio_codigo_2102804  municipio_codigo_2103000  \
# 2057437                         0                         0
#
#          municipio_codigo_2103174  municipio_codigo_2103208  \
# 2057437                         0                         0
#
#          municipio_codigo_2103307  municipio_codigo_2103505  \
# 2057437                         0                         0
#
#          municipio_codigo_2103604  municipio_codigo_2103752  \
# 2057437                         0                         0
#
#          municipio_codigo_2104057  municipio_codigo_2104206  \
# 2057437                         0                         0
#
#          municipio_codigo_2104503  municipio_codigo_2104677  \
# 2057437                         0                         0
#
#          municipio_codigo_2104800  municipio_codigo_2105302  \
# 2057437                         0                         0
#
#          municipio_codigo_2105401  municipio_codigo_2105427  \
# 2057437                         0                         0
#
#          municipio_codigo_2105500  municipio_codigo_2105708  \
# 2057437                         0                         0
#
#          municipio_codigo_2105906  municipio_codigo_2105948  \
# 2057437                         0                         0
#
#          municipio_codigo_2106102  municipio_codigo_2106755  \
# 2057437                         0                         0
#
#          municipio_codigo_2107506  municipio_codigo_2107803  \
# 2057437                         0                         0
#
#          municipio_codigo_2108207  municipio_codigo_2108603  \
# 2057437                         0                         0
#
#          municipio_codigo_2108702  municipio_codigo_2109007  \
# 2057437                         0                         0
#
#          municipio_codigo_2109106  municipio_codigo_2109270  \
# 2057437                         0                         0
#
#          municipio_codigo_2109502  municipio_codigo_2109601  \
# 2057437                         0                         0
#
#          municipio_codigo_2109908  municipio_codigo_2110203  \
# 2057437                         0                         0
#
#          municipio_codigo_2110302  municipio_codigo_2110609  \
# 2057437                         0                         0
#
#          municipio_codigo_2110658  municipio_codigo_2111052  \
# 2057437                         0                         0
#
#          municipio_codigo_2111201  municipio_codigo_2111300  \
# 2057437                         0                         0
#
#          municipio_codigo_2111573  municipio_codigo_2111607  \
# 2057437                         0                         0
#
#          municipio_codigo_2111763  municipio_codigo_2111805  \
# 2057437                         0                         0
#
#          municipio_codigo_2112001  municipio_codigo_2112209  \
# 2057437                         0                         0
#
#          municipio_codigo_2112233  municipio_codigo_2112605  \
# 2057437                         0                         0
#
#          municipio_codigo_2112704  municipio_codigo_2112803  \
# 2057437                         0                         0
#
#          municipio_codigo_2112902  municipio_codigo_2113009  \
# 2057437                         0                         0
#
#          municipio_codigo_2114007  municipio_codigo_2200202  \
# 2057437                         0                         0
#
#          municipio_codigo_2200400  municipio_codigo_2201150  \
# 2057437                         0                         0
#
#          municipio_codigo_2201903  municipio_codigo_2202604  \
# 2057437                         0                         0
#
#          municipio_codigo_2202901  municipio_codigo_2203909  \
# 2057437                         0                         0
#
#          municipio_codigo_2204105  municipio_codigo_2204204  \
# 2057437                         0                         0
#
#          municipio_codigo_2204402  municipio_codigo_2204709  \
# 2057437                         0                         0
#
#          municipio_codigo_2205102  municipio_codigo_2206654  \
# 2057437                         0                         0
#
#          municipio_codigo_2207009  municipio_codigo_2207504  \
# 2057437                         0                         0
#
#          municipio_codigo_2207702  municipio_codigo_2207801  \
# 2057437                         0                         0
#
#          municipio_codigo_2207900  municipio_codigo_2208007  \
# 2057437                         0                         0
#
#          municipio_codigo_2208304  municipio_codigo_2208403  \
# 2057437                         0                         0
#
#          municipio_codigo_2208700  municipio_codigo_2208809  \
# 2057437                         0                         0
#
#          municipio_codigo_2208908  municipio_codigo_2209005  \
# 2057437                         0                         0
#
#          municipio_codigo_2209104  municipio_codigo_2209203  \
# 2057437                         0                         0
#
#          municipio_codigo_2209302  municipio_codigo_2211001  \
# 2057437                         0                         0
#
#          municipio_codigo_2211100  municipio_codigo_2300150  \
# 2057437                         0                         0
#
#          municipio_codigo_2300200  municipio_codigo_2300754  \
# 2057437                         0                         0
#
#          municipio_codigo_2301000  municipio_codigo_2301109  \
# 2057437                         0                         0
#
#          municipio_codigo_2301901  municipio_codigo_2302057  \
# 2057437                         0                         0
#
#          municipio_codigo_2302107  municipio_codigo_2302206  \
# 2057437                         0                         0
#
#          municipio_codigo_2302305  municipio_codigo_2302503  \
# 2057437                         0                         0
#
#          municipio_codigo_2302602  municipio_codigo_2302800  \
# 2057437                         0                         0
#
#          municipio_codigo_2302909  municipio_codigo_2303501  \
# 2057437                         0                         0
#
#          municipio_codigo_2303659  municipio_codigo_2303709  \
# 2057437                         0                         0
#
#          municipio_codigo_2303907  municipio_codigo_2304103  \
# 2057437                         0                         0
#
#          municipio_codigo_2304202  municipio_codigo_2304285  \
# 2057437                         0                         0
#
#          municipio_codigo_2304350  municipio_codigo_2304400  \
# 2057437                         0                         0
#
#          municipio_codigo_2304608  municipio_codigo_2305001  \
# 2057437                         0                         0
#
#          municipio_codigo_2305233  municipio_codigo_2305357  \
# 2057437                         0                         0
#
#          municipio_codigo_2305506  municipio_codigo_2305803  \
# 2057437                         0                         0
#
#          municipio_codigo_2306256  municipio_codigo_2306306  \
# 2057437                         0                         0
#
#          municipio_codigo_2306405  municipio_codigo_2306553  \
# 2057437                         0                         0
#
#          municipio_codigo_2306801  municipio_codigo_2306900  \
# 2057437                         0                         0
#
#          municipio_codigo_2307007  municipio_codigo_2307254  \
# 2057437                         0                         0
#
#          municipio_codigo_2307304  municipio_codigo_2307403  \
# 2057437                         0                         0
#
#          municipio_codigo_2307601  municipio_codigo_2307635  \
# 2057437                         0                         0
#
#          municipio_codigo_2307650  municipio_codigo_2307700  \
# 2057437                         0                         0
#
#          municipio_codigo_2308005  municipio_codigo_2308401  \
# 2057437                         0                         0
#
#          municipio_codigo_2308708  municipio_codigo_2309409  \
# 2057437                         0                         0
#
#          municipio_codigo_2309607  municipio_codigo_2309706  \
# 2057437                         0                         0
#
#          municipio_codigo_2309805  municipio_codigo_2309904  \
# 2057437                         0                         0
#
#          municipio_codigo_2310209  municipio_codigo_2310258  \
# 2057437                         0                         0
#
#          municipio_codigo_2310506  municipio_codigo_2310605  \
# 2057437                         0                         0
#
#          municipio_codigo_2310704  municipio_codigo_2310803  \
# 2057437                         0                         0
#
#          municipio_codigo_2310852  municipio_codigo_2310902  \
# 2057437                         0                         0
#
#          municipio_codigo_2311306  municipio_codigo_2311405  \
# 2057437                         0                         0
#
#          municipio_codigo_2311504  municipio_codigo_2311603  \
# 2057437                         0                         0
#
#          municipio_codigo_2311801  municipio_codigo_2312205  \
# 2057437                         0                         0
#
#          municipio_codigo_2312403  municipio_codigo_2312700  \
# 2057437                         0                         0
#
#          municipio_codigo_2312908  municipio_codigo_2313302  \
# 2057437                         0                         0
#
#          municipio_codigo_2313401  municipio_codigo_2313500  \
# 2057437                         0                         0
#
#          municipio_codigo_2313609  municipio_codigo_2313807  \
# 2057437                         0                         0
#
#          municipio_codigo_2313906  municipio_codigo_2400208  \
# 2057437                         0                         0
#
#          municipio_codigo_2400604  municipio_codigo_2401008  \
# 2057437                         0                         0
#
#          municipio_codigo_2401107  municipio_codigo_2401453  \
# 2057437                         0                         0
#
#          municipio_codigo_2402006  municipio_codigo_2402204  \
# 2057437                         0                         0
#
#          municipio_codigo_2402600  municipio_codigo_2402709  \
# 2057437                         0                         0
#
#          municipio_codigo_2403103  municipio_codigo_2403251  \
# 2057437                         0                         0
#
#          municipio_codigo_2403608  municipio_codigo_2404101  \
# 2057437                         0                         0
#
#          municipio_codigo_2404507  municipio_codigo_2405702  \
# 2057437                         0                         0
#
#          municipio_codigo_2406700  municipio_codigo_2407005  \
# 2057437                         0                         0
#
#          municipio_codigo_2407104  municipio_codigo_2407203  \
# 2057437                         0                         0
#
#          municipio_codigo_2407401  municipio_codigo_2407609  \
# 2057437                         0                         0
#
#          municipio_codigo_2408003  municipio_codigo_2408102  \
# 2057437                         0                         0
#
#          municipio_codigo_2408904  municipio_codigo_2409332  \
# 2057437                         0                         0
#
#          municipio_codigo_2409407  municipio_codigo_2410207  \
# 2057437                         0                         0
#
#          municipio_codigo_2410306  municipio_codigo_2411403  \
# 2057437                         0                         0
#
#          municipio_codigo_2412005  municipio_codigo_2412203  \
# 2057437                         0                         0
#
#          municipio_codigo_2412500  municipio_codigo_2412609  \
# 2057437                         0                         0
#
#          municipio_codigo_2413359  municipio_codigo_2414001  \
# 2057437                         0                         0
#
#          municipio_codigo_2414209  municipio_codigo_2414407  \
# 2057437                         0                         0
#
#          municipio_codigo_2500106  municipio_codigo_2500536  \
# 2057437                         0                         0
#
#          municipio_codigo_2500601  municipio_codigo_2501609  \
# 2057437                         0                         0
#
#          municipio_codigo_2501807  municipio_codigo_2502151  \
# 2057437                         0                         0
#
#          municipio_codigo_2502706  municipio_codigo_2503001  \
# 2057437                         0                         0
#
#          municipio_codigo_2503209  municipio_codigo_2503704  \
# 2057437                         0                         0
#
#          municipio_codigo_2504009  municipio_codigo_2504306  \
# 2057437                         0                         0
#
#          municipio_codigo_2504405  municipio_codigo_2504603  \
# 2057437                         0                         0
#
#          municipio_codigo_2506004  municipio_codigo_2506301  \
# 2057437                         0                         0
#
#          municipio_codigo_2506707  municipio_codigo_2506905  \
# 2057437                         0                         0
#
#          municipio_codigo_2507507  municipio_codigo_2507705  \
# 2057437                         0                         0
#
#          municipio_codigo_2508901  municipio_codigo_2509008  \
# 2057437                         0                         0
#
#          municipio_codigo_2509503  municipio_codigo_2509701  \
# 2057437                         0                         0
#
#          municipio_codigo_2510808  municipio_codigo_2510907  \
# 2057437                         0                         0
#
#          municipio_codigo_2511301  municipio_codigo_2511400  \
# 2057437                         0                         0
#
#          municipio_codigo_2511509  municipio_codigo_2512002  \
# 2057437                         0                         0
#
#          municipio_codigo_2512101  municipio_codigo_2512507  \
# 2057437                         0                         0
#
#          municipio_codigo_2512705  municipio_codigo_2512762  \
# 2057437                         0                         0
#
#          municipio_codigo_2512903  municipio_codigo_2513208  \
# 2057437                         0                         0
#
#          municipio_codigo_2513703  municipio_codigo_2513851  \
# 2057437                         0                         0
#
#          municipio_codigo_2513901  municipio_codigo_2514206  \
# 2057437                         0                         0
#
#          municipio_codigo_2515971  municipio_codigo_2516201  \
# 2057437                         0                         0
#
#          municipio_codigo_2516706  municipio_codigo_2516904  \
# 2057437                         0                         0
#
#          municipio_codigo_2600054  municipio_codigo_2600104  \
# 2057437                         0                         0
#
#          municipio_codigo_2600302  municipio_codigo_2600401  \
# 2057437                         0                         0
#
#          municipio_codigo_2600708  municipio_codigo_2601102  \
# 2057437                         0                         0
#
#          municipio_codigo_2601201  municipio_codigo_2601409  \
# 2057437                         0                         0
#
#          municipio_codigo_2601607  municipio_codigo_2601706  \
# 2057437                         0                         0
#
#          municipio_codigo_2601904  municipio_codigo_2602001  \
# 2057437                         0                         0
#
#          municipio_codigo_2602100  municipio_codigo_2602209  \
# 2057437                         0                         0
#
#          municipio_codigo_2602407  municipio_codigo_2602506  \
# 2057437                         0                         0
#
#          municipio_codigo_2602902  municipio_codigo_2603009  \
# 2057437                         0                         0
#
#          municipio_codigo_2603108  municipio_codigo_2603207  \
# 2057437                         0                         0
#
#          municipio_codigo_2603454  municipio_codigo_2603603  \
# 2057437                         0                         0
#
#          municipio_codigo_2604007  municipio_codigo_2604106  \
# 2057437                         0                         0
#
#          municipio_codigo_2604205  municipio_codigo_2605004  \
# 2057437                         0                         0
#
#          municipio_codigo_2605202  municipio_codigo_2605400  \
# 2057437                         0                         0
#
#          municipio_codigo_2605459  municipio_codigo_2605608  \
# 2057437                         0                         0
#
#          municipio_codigo_2605905  municipio_codigo_2606002  \
# 2057437                         0                         0
#
#          municipio_codigo_2606101  municipio_codigo_2606200  \
# 2057437                         0                         0
#
#          municipio_codigo_2606408  municipio_codigo_2606507  \
# 2057437                         0                         0
#
#          municipio_codigo_2606804  municipio_codigo_2607208  \
# 2057437                         0                         0
#
#          municipio_codigo_2607604  municipio_codigo_2607752  \
# 2057437                         0                         0
#
#          municipio_codigo_2607901  municipio_codigo_2608503  \
# 2057437                         0                         0
#
#          municipio_codigo_2608909  municipio_codigo_2609204  \
# 2057437                         0                         0
#
#          municipio_codigo_2609402  municipio_codigo_2609501  \
# 2057437                         0                         0
#
#          municipio_codigo_2609600  municipio_codigo_2609907  \
# 2057437                         0                         0
#
#          municipio_codigo_2610004  municipio_codigo_2610509  \
# 2057437                         0                         0
#
#          municipio_codigo_2610707  municipio_codigo_2610806  \
# 2057437                         0                         0
#
#          municipio_codigo_2610905  municipio_codigo_2611101  \
# 2057437                         0                         0
#
#          municipio_codigo_2611606  municipio_codigo_2611804  \
# 2057437                         0                         0
#
#          municipio_codigo_2612406  municipio_codigo_2612471  \
# 2057437                         0                         0
#
#          municipio_codigo_2613008  municipio_codigo_2613206  \
# 2057437                         0                         0
#
#          municipio_codigo_2613305  municipio_codigo_2613404  \
# 2057437                         0                         0
#
#          municipio_codigo_2613503  municipio_codigo_2613602  \
# 2057437                         0                         0
#
#          municipio_codigo_2613701  municipio_codigo_2613800  \
# 2057437                         0                         0
#
#          municipio_codigo_2613909  municipio_codigo_2614204  \
# 2057437                         0                         0
#
#          municipio_codigo_2614303  municipio_codigo_2614501  \
# 2057437                         0                         0
#
#          municipio_codigo_2614808  municipio_codigo_2614857  \
# 2057437                         0                         0
#
#          municipio_codigo_2615003  municipio_codigo_2615607  \
# 2057437                         0                         0
#
#          municipio_codigo_2615805  municipio_codigo_2616407  \
# 2057437                         0                         0
#
#          municipio_codigo_2700300  municipio_codigo_2700409  \
# 2057437                         0                         0
#
#          municipio_codigo_2700805  municipio_codigo_2701001  \
# 2057437                         0                         0
#
#          municipio_codigo_2701308  municipio_codigo_2701506  \
# 2057437                         0                         0
#
#          municipio_codigo_2701605  municipio_codigo_2701704  \
# 2057437                         0                         0
#
#          municipio_codigo_2701803  municipio_codigo_2702306  \
# 2057437                         0                         0
#
#          municipio_codigo_2702405  municipio_codigo_2703007  \
# 2057437                         0                         0
#
#          municipio_codigo_2703106  municipio_codigo_2703502  \
# 2057437                         0                         0
#
#          municipio_codigo_2704302  municipio_codigo_2704500  \
# 2057437                         0                         0
#
#          municipio_codigo_2704807  municipio_codigo_2705200  \
# 2057437                         0                         0
#
#          municipio_codigo_2706307  municipio_codigo_2706604  \
# 2057437                         0                         0
#
#          municipio_codigo_2707602  municipio_codigo_2707701  \
# 2057437                         0                         0
#
#          municipio_codigo_2707909  municipio_codigo_2708303  \
# 2057437                         0                         0
#
#          municipio_codigo_2708402  municipio_codigo_2708600  \
# 2057437                         0                         0
#
#          municipio_codigo_2708808  municipio_codigo_2708907  \
# 2057437                         0                         0
#
#          municipio_codigo_2708956  municipio_codigo_2709301  \
# 2057437                         0                         0
#
#          municipio_codigo_2800308  municipio_codigo_2800670  \
# 2057437                         0                         0
#
#          municipio_codigo_2801009  municipio_codigo_2801306  \
# 2057437                         0                         0
#
#          municipio_codigo_2801702  municipio_codigo_2802106  \
# 2057437                         0                         0
#
#          municipio_codigo_2802304  municipio_codigo_2802908  \
# 2057437                         0                         0
#
#          municipio_codigo_2803005  municipio_codigo_2803401  \
# 2057437                         0                         0
#
#          municipio_codigo_2803500  municipio_codigo_2804409  \
# 2057437                         0                         0
#
#          municipio_codigo_2804508  municipio_codigo_2804607  \
# 2057437                         0                         0
#
#          municipio_codigo_2804805  municipio_codigo_2805208  \
# 2057437                         0                         0
#
#          municipio_codigo_2805703  municipio_codigo_2806008  \
# 2057437                         0                         0
#
#          municipio_codigo_2806206  municipio_codigo_2806701  \
# 2057437                         0                         0
#
#          municipio_codigo_2807006  municipio_codigo_2807402  \
# 2057437                         0                         0
#
#          municipio_codigo_2900108  municipio_codigo_2900702  \
# 2057437                         0                         0
#
#          municipio_codigo_2900801  municipio_codigo_2901106  \
# 2057437                         0                         0
#
#          municipio_codigo_2901403  municipio_codigo_2901601  \
# 2057437                         0                         0
#
#          municipio_codigo_2902054  municipio_codigo_2902104  \
# 2057437                         0                         0
#
#          municipio_codigo_2902401  municipio_codigo_2902500  \
# 2057437                         0                         0
#
#          municipio_codigo_2902708  municipio_codigo_2902807  \
# 2057437                         0                         0
#
#          municipio_codigo_2902906  municipio_codigo_2903201  \
# 2057437                         0                         0
#
#          municipio_codigo_2903904  municipio_codigo_2904605  \
# 2057437                         0                         0
#
#          municipio_codigo_2905008  municipio_codigo_2905206  \
# 2057437                         0                         0
#
#          municipio_codigo_2905701  municipio_codigo_2906006  \
# 2057437                         0                         0
#
#          municipio_codigo_2906303  municipio_codigo_2906501  \
# 2057437                         0                         0
#
#          municipio_codigo_2906600  municipio_codigo_2906709  \
# 2057437                         0                         0
#
#          municipio_codigo_2906873  municipio_codigo_2906907  \
# 2057437                         0                         0
#
#          municipio_codigo_2907509  municipio_codigo_2907806  \
# 2057437                         0                         0
#
#          municipio_codigo_2908101  municipio_codigo_2908200  \
# 2057437                         0                         0
#
#          municipio_codigo_2908408  municipio_codigo_2908507  \
# 2057437                         0                         0
#
#          municipio_codigo_2908606  municipio_codigo_2908705  \
# 2057437                         0                         0
#
#          municipio_codigo_2909000  municipio_codigo_2909307  \
# 2057437                         0                         0
#
#          municipio_codigo_2909406  municipio_codigo_2909802  \
# 2057437                         0                         0
#
#          municipio_codigo_2910057  municipio_codigo_2910107  \
# 2057437                         0                         0
#
#          municipio_codigo_2910503  municipio_codigo_2910701  \
# 2057437                         0                         0
#
#          municipio_codigo_2910727  municipio_codigo_2910800  \
# 2057437                         0                         0
#
#          municipio_codigo_2911105  municipio_codigo_2911204  \
# 2057437                         0                         0
#
#          municipio_codigo_2911402  municipio_codigo_2911709  \
# 2057437                         0                         0
#
#          municipio_codigo_2911907  municipio_codigo_2912004  \
# 2057437                         0                         0
#
#          municipio_codigo_2912202  municipio_codigo_2913200  \
# 2057437                         0                         0
#
#          municipio_codigo_2913408  municipio_codigo_2913507  \
# 2057437                         0                         0
#
#          municipio_codigo_2913606  municipio_codigo_2913705  \
# 2057437                         0                         0
#
#          municipio_codigo_2913804  municipio_codigo_2913903  \
# 2057437                         0                         0
#
#          municipio_codigo_2914000  municipio_codigo_2914406  \
# 2057437                         0                         0
#
#          municipio_codigo_2914505  municipio_codigo_2914604  \
# 2057437                         0                         0
#
#          municipio_codigo_2914653  municipio_codigo_2914703  \
# 2057437                         0                         0
#
#          municipio_codigo_2914802  municipio_codigo_2914901  \
# 2057437                         0                         0
#
#          municipio_codigo_2915304  municipio_codigo_2915601  \
# 2057437                         0                         0
#
#          municipio_codigo_2915908  municipio_codigo_2916104  \
# 2057437                         0                         0
#
#          municipio_codigo_2916401  municipio_codigo_2916856  \
# 2057437                         0                         0
#
#          municipio_codigo_2917334  municipio_codigo_2917359  \
# 2057437                         0                         0
#
#          municipio_codigo_2917508  municipio_codigo_2917607  \
# 2057437                         0                         0
#
#          municipio_codigo_2917706  municipio_codigo_2918001  \
# 2057437                         0                         0
#
#          municipio_codigo_2918100  municipio_codigo_2918357  \
# 2057437                         0                         0
#
#          municipio_codigo_2918407  municipio_codigo_2918753  \
# 2057437                         0                         0
#
#          municipio_codigo_2919207  municipio_codigo_2919504  \
# 2057437                         0                         0
#
#          municipio_codigo_2919553  municipio_codigo_2919702  \
# 2057437                         0                         0
#
#          municipio_codigo_2919801  municipio_codigo_2919926  \
# 2057437                         0                         0
#
#          municipio_codigo_2920205  municipio_codigo_2920304  \
# 2057437                         0                         0
#
#          municipio_codigo_2920908  municipio_codigo_2921005  \
# 2057437                         0                         0
#
#          municipio_codigo_2921104  municipio_codigo_2921203  \
# 2057437                         0                         0
#
#          municipio_codigo_2921401  municipio_codigo_2921609  \
# 2057437                         0                         0
#
#          municipio_codigo_2921807  municipio_codigo_2922003  \
# 2057437                         0                         0
#
#          municipio_codigo_2922201  municipio_codigo_2922250  \
# 2057437                         0                         0
#
#          municipio_codigo_2922409  municipio_codigo_2922706  \
# 2057437                         0                         0
#
#          municipio_codigo_2922854  municipio_codigo_2923001  \
# 2057437                         0                         0
#
#          municipio_codigo_2923357  municipio_codigo_2923605  \
# 2057437                         0                         0
#
#          municipio_codigo_2923902  municipio_codigo_2924009  \
# 2057437                         0                         0
#
#          municipio_codigo_2924306  municipio_codigo_2924678  \
# 2057437                         0                         0
#
#          municipio_codigo_2924900  municipio_codigo_2925006  \
# 2057437                         0                         0
#
#          municipio_codigo_2925105  municipio_codigo_2925204  \
# 2057437                         0                         0
#
#          municipio_codigo_2925253  municipio_codigo_2925303  \
# 2057437                         0                         0
#
#          municipio_codigo_2925402  municipio_codigo_2925501  \
# 2057437                         0                         0
#
#          municipio_codigo_2925600  municipio_codigo_2926301  \
# 2057437                         0                         0
#
#          municipio_codigo_2926400  municipio_codigo_2926608  \
# 2057437                         0                         0
#
#          municipio_codigo_2926806  municipio_codigo_2926905  \
# 2057437                         0                         0
#
#          municipio_codigo_2927002  municipio_codigo_2927200  \
# 2057437                         0                         0
#
#          municipio_codigo_2927408  municipio_codigo_2927705  \
# 2057437                         0                         0
#
#          municipio_codigo_2927903  municipio_codigo_2928000  \
# 2057437                         0                         0
#
#          municipio_codigo_2928109  municipio_codigo_2928208  \
# 2057437                         0                         0
#
#          municipio_codigo_2928604  municipio_codigo_2928703  \
# 2057437                         0                         0
#
#          municipio_codigo_2928802  municipio_codigo_2928901  \
# 2057437                         0                         0
#
#          municipio_codigo_2929305  municipio_codigo_2929503  \
# 2057437                         0                         0
#
#          municipio_codigo_2929909  municipio_codigo_2930105  \
# 2057437                         0                         0
#
#          municipio_codigo_2930501  municipio_codigo_2930709  \
# 2057437                         0                         0
#
#          municipio_codigo_2930758  municipio_codigo_2930774  \
# 2057437                         0                         0
#
#          municipio_codigo_2931004  municipio_codigo_2931350  \
# 2057437                         0                         0
#
#          municipio_codigo_2931806  municipio_codigo_2932101  \
# 2057437                         0                         0
#
#          municipio_codigo_2932309  municipio_codigo_2932408  \
# 2057437                         0                         0
#
#          municipio_codigo_2932606  municipio_codigo_2932903  \
# 2057437                         0                         0
#
#          municipio_codigo_2933059  municipio_codigo_2933307  \
# 2057437                         0                         0
#
#          municipio_codigo_3100104  municipio_codigo_3100203  \
# 2057437                         0                         0
#
#          municipio_codigo_3100302  municipio_codigo_3100401  \
# 2057437                         0                         0
#
#          municipio_codigo_3100500  municipio_codigo_3100609  \
# 2057437                         0                         0
#
#          municipio_codigo_3100807  municipio_codigo_3100906  \
# 2057437                         0                         0
#
#          municipio_codigo_3101102  municipio_codigo_3101300  \
# 2057437                         0                         0
#
#          municipio_codigo_3101508  municipio_codigo_3101607  \
# 2057437                         0                         0
#
#          municipio_codigo_3101631  municipio_codigo_3101706  \
# 2057437                         0                         0
#
#          municipio_codigo_3101805  municipio_codigo_3101904  \
# 2057437                         0                         0
#
#          municipio_codigo_3102001  municipio_codigo_3102100  \
# 2057437                         0                         0
#
#          municipio_codigo_3102308  municipio_codigo_3102605  \
# 2057437                         0                         0
#
#          municipio_codigo_3102704  municipio_codigo_3102803  \
# 2057437                         0                         0
#
#          municipio_codigo_3102852  municipio_codigo_3102902  \
# 2057437                         0                         0
#
#          municipio_codigo_3103009  municipio_codigo_3103207  \
# 2057437                         0                         0
#
#          municipio_codigo_3103405  municipio_codigo_3103504  \
# 2057437                         0                         0
#
#          municipio_codigo_3103702  municipio_codigo_3103751  \
# 2057437                         0                         0
#
#          municipio_codigo_3103801  municipio_codigo_3103900  \
# 2057437                         0                         0
#
#          municipio_codigo_3104007  municipio_codigo_3104205  \
# 2057437                         0                         0
#
#          municipio_codigo_3104304  municipio_codigo_3104502  \
# 2057437                         0                         0
#
#          municipio_codigo_3104601  municipio_codigo_3104700  \
# 2057437                         0                         0
#
#          municipio_codigo_3105004  municipio_codigo_3105103  \
# 2057437                         0                         0
#
#          municipio_codigo_3105301  municipio_codigo_3105400  \
# 2057437                         0                         0
#
#          municipio_codigo_3105608  municipio_codigo_3105905  \
# 2057437                         0                         0
#
#          municipio_codigo_3106002  municipio_codigo_3106200  \
# 2057437                         0                         0
#
#          municipio_codigo_3106309  municipio_codigo_3106408  \
# 2057437                         0                         0
#
#          municipio_codigo_3106507  municipio_codigo_3106705  \
# 2057437                         0                         0
#
#          municipio_codigo_3106903  municipio_codigo_3107109  \
# 2057437                         0                         0
#
#          municipio_codigo_3107307  municipio_codigo_3107406  \
# 2057437                         0                         0
#
#          municipio_codigo_3107505  municipio_codigo_3107703  \
# 2057437                         0                         0
#
#          municipio_codigo_3107802  municipio_codigo_3107901  \
# 2057437                         0                         0
#
#          municipio_codigo_3108008  municipio_codigo_3108107  \
# 2057437                         0                         0
#
#          municipio_codigo_3108305  municipio_codigo_3108404  \
# ...
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO BV S.A.  \
# 2057437                                                 0
#
#          instituicao_financeira_credenciada_BANCO CAIXA GERAL - BRASIL S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO CATERPILLAR S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO CITIBANK S/A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO CNH INDUSTRIAL CAPITAL S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO COOPERATIVO SICOOB S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO COOPERATIVO SICREDI S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO DA AMAZONIA SA  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO DAYCOVAL S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO DE DESENVOLVIMENTO DE MINAS GERAIS S.A. - BDMG  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO DE DESENVOLVIMENTO DO ESPIRITO SANTO S/A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO DE LAGE LANDEN BRASIL S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO DO BRASIL SA  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO DO ESTADO DO RIO GRANDE DO SUL SA  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO DO NORDESTE DO BRASIL SA  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO INDUSTRIAL DO BRASIL S/A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO INDUSVAL SA  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO ITAUBANK S.A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO ITAULEASING S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO J. SAFRA S.A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO JOHN DEERE S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO KOMATSU DO BRASIL S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO MERCANTIL DO BRASIL SA  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO MERCEDES-BENZ DO BRASIL S/A  \
# 2057437                                                  1
#
#          instituicao_financeira_credenciada_BANCO MONEO S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO MUFG BRASIL S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO PINE S/A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO RABOBANK INTERNATIONAL BRASIL S/A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO RANDON S/A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO RENDIMENTO S/A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO RIBEIRAO PRETO S/A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO RODOBENS S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO SAFRA S A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO SANTANDER (BRASIL) S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO SUMITOMO MITSUI BRASILEIRO S A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO TRIANGULO S/A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO VOLKSWAGEN S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO VOLVO (BRASIL) S.A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANCO VOTORANTIM S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BANESTES SA BANCO DO ESTADO DO ESPIRITO SANTO  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BB.LEASING S.A.ARRENDAMENTO MERCANTIL  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BRADESCO LEASING S.A. - ARRENDAMENTO MERCANTIL  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_BRB BANCO DE BRASILIA SA  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_CAIXA ECONOMICA FEDERAL  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_CHINA CONSTRUCTION BANK (BRASIL) BANCO MULTIPLO S/A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_COOPERATIVA CENTRAL DE CREDITO - AILOS  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_COOPERATIVA CENTRAL DE CREDITO RURAL COM INT (01401771)  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_COOPERATIVA CENTRAL DE CREDITO RURAL COM INT (21198087)  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_COOPERATIVA CENTRAL DE CREDITO RURAL COM INTERACAO SOLI  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_DESENBAHIA-AGENCIA DE FOMENTO DO ESTADO DA BAHIA S/A  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_DESENVOLVE SP - AGENCIA DE FOMENTO DO ESTADO DE SAO PAU  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_DIBENS LEASING S/A - ARRENDAMENTO MERCANTIL  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_FINANCEIRA ALFA S.A. CREDITO, FINANCIAMENTO E INVESTIME  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_ITAU UNIBANCO S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_KIRTON BANK S.A. - BANCO MULTIPLO  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_MASSA FALIDA DO BANCO SANTOS  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_MERCEDES-BENZ LEASING DO BRASIL ARRENDAMENTO MERCANTIL  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_SAFRA LEASING S.A. ARRENDAMENTO MERCANTIL  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_SCANIA BANCO S.A.  \
# 2057437                                                  0
#
#          instituicao_financeira_credenciada_SEM NOME  \
# 2057437                                            0
#
#          instituicao_financeira_credenciada_SOLUTO II PARTICIPACOES S/A - EM LIQUIDACAO ORDINARIA E  \
# 2057437                                                  0
#
#          instrumento_financeiro_AQUISIÇÃO DE BENS DE CAPITAL: INDÚSTRIA, COMÉRCIO E SERVIÇOS  \
# 2057437                                                  0
#
#          instrumento_financeiro_BK AQUISIÇÃO E COMERCIALIZAÇÃO  \
# 2057437                                                  1
#
#          instrumento_financeiro_BNDES CEREALISTAS  \
# 2057437                                         0
#
#          instrumento_financeiro_BNDES CEREALISTAS - Equalizado  \
# 2057437                                                  0
#
#          instrumento_financeiro_BNDES GIRO  \
# 2057437                                  0
#
#          instrumento_financeiro_BNDES MPE APRENDIZ  \
# 2057437                                          0
#
#          instrumento_financeiro_BNDES MPME INOVADORA  \
# 2057437                                            0
#
#          instrumento_financeiro_BNDES PASS  \
# 2057437                                  0
#
#          instrumento_financeiro_BNDES PER BR  \
# 2057437                                    0
#
#          instrumento_financeiro_BNDES PER BR - Equalizado  \
# 2057437                                                 0
#
#          instrumento_financeiro_BNDES PMAT AUTOMÁTICO  \
# 2057437                                             0
#
#          instrumento_financeiro_BNDES PROCAMINHONEIRO  \
# 2057437                                             0
#
#          instrumento_financeiro_BNDES PROCAMINHONEIRO - Equalizado  \
# 2057437                                                  0
#
#          instrumento_financeiro_BNDES PROFARMA  \
# 2057437                                      0
#
#          instrumento_financeiro_BNDES PROSOFT  \
# 2057437                                     0
#
#          instrumento_financeiro_BNDES REVITALIZA  \
# 2057437                                        0
#
#          instrumento_financeiro_BNDES SAÚDE  \
# 2057437                                   0
#
#          instrumento_financeiro_CAPACIDADE PRODUTIVA - Indústria de Bens de Capital  \
# 2057437                                                  0
#
#          instrumento_financeiro_CAPACIDADE PRODUTIVA NA INDÚSTRIA,AGRICULTURA,COMÉRCIO E SERVIÇOS  \
# 2057437                                                  0
#
#          instrumento_financeiro_INDÚSTRIA, AGROPECUÁRIA E INFRAESTRUTURA  \
# 2057437                                                  0
#
#          instrumento_financeiro_INOVAGRO  \
# 2057437                                0
#
#          instrumento_financeiro_LINHA EMPRÉSTIMO PARA MICRO E PEQUENAS EMPRESAS  \
# 2057437                                                  0
#
#          instrumento_financeiro_MATERIAIS INDUSTRIALIZADOS  \
# 2057437                                                  0
#
#          instrumento_financeiro_MICRO, PEQUENAS E MÉDIAS EMPRESAS  \
# 2057437                                                  0
#
#          instrumento_financeiro_MODERAGRO  instrumento_financeiro_MODERFROTA  \
# 2057437                                 0                                  0
#
#          instrumento_financeiro_MODERINFRA  instrumento_financeiro_MODERMAQ  \
# 2057437                                  0                                0
#
#          instrumento_financeiro_MÉDIAS-GRANDES E GRANDES EMPRESAS – DEMAIS SETORES  \
# 2057437                                                  0
#
#          instrumento_financeiro_MÉDIAS-GRANDES E GRANDES EMPRESAS – SETORES PRIORITÁRIOS  \
# 2057437                                                  0
#
#          instrumento_financeiro_OUTROS  instrumento_financeiro_PEC BNDES  \
# 2057437                              0                                 0
#
#          instrumento_financeiro_PROCAP-AGRO  \
# 2057437                                   0
#
#          instrumento_financeiro_PROCAPCRED  instrumento_financeiro_PRODECOOP  \
# 2057437                                  0                                 0
#
#          instrumento_financeiro_PRODUSA  instrumento_financeiro_PROGRAMA ABC  \
# 2057437                               0                                    0
#
#          instrumento_financeiro_PROGRAMA FUNDO CLIMA  \
# 2057437                                            0
#
#          instrumento_financeiro_PROGRAMA IES  \
# 2057437                                    0
#
#          instrumento_financeiro_PROGRAMA PARA CONSTRUÇÃO E AMPLIAÇÃO DE ARMAZÉNS - PCA  \
# 2057437                                                  0
#
#          instrumento_financeiro_PRONAF CUSTEIO  \
# 2057437                                      0
#
#          instrumento_financeiro_PRONAF INVESTIMENTO  \
# 2057437                                           0
#
#          instrumento_financeiro_PRONAMP INVESTIMENTO  \
# 2057437                                            0
#
#          instrumento_financeiro_PROPFLORA  \
# 2057437                                 0
#
#          instrumento_financeiro_PRÓ-CDD MAÇA  \
# 2057437                                    0
#
#          instrumento_financeiro_PSI - BK - Demais Itens  \
# 2057437                                               0
#
#          instrumento_financeiro_PSI - BK - Rural  \
# 2057437                                        0
#
#          instrumento_financeiro_PSI - BK - Tecnologia Nacional  \
# 2057437                                                  0
#
#          instrumento_financeiro_PSI - BK - Ônibus e Caminhão  \
# 2057437                                                  0
#
#          instrumento_financeiro_PSI - Inovação  \
# 2057437                                      0
#
#          instrumento_financeiro_PSI - Inovação - BK Eficientes  \
# 2057437                                                  0
#
#          instrumento_financeiro_TURISMO, COMÉRCIO E SERVIÇOS
# 2057437                                                  0

# %%
df.head(1)
# Out:
#     uf  municipio_codigo data_da_contratacao  valor_da_operacao_em_reais  \
# 36  RS           4321808          2002-01-02                        2303
#
#    valor_desembolsado_reais                   fonte_de_recurso_desembolsos  \
# 36                   2303,0  RECURSOS VINCULADOS - FAT DEPÓSITOS ESPECIAIS
#
#    custo_financeiro  juros prazo_carencia_meses prazo_amortizacao_meses  \
# 36        TAXA FIXA    4.0               0 days      1460 days 23:16:48
#
#    modalidade_de_apoio forma_de_apoio           produto  \
# 36        REEMBOLSÁVEL       INDIRETA  BNDES AUTOMÁTICO
#
#    instrumento_financeiro inovacao                     area_operacional  \
# 36    PRONAF INVESTIMENTO      NÃO  AREA DE OPERACOES E CANAIS DIGITAIS
#
#               setor_cnae subsetor_cnae_agrupado subsetor_cnae_codigo  \
# 36  AGROPECUÁRIA E PESCA           Agropecuária             A0100000
#
#                                subsetor_cnae_nome   setor_bndes  \
# 36  AGRICULTURA, PECUARIA E SERVICOS RELACIONADOS  AGROPECUÁRIA
#
#    subsetor_bndes porte_do_cliente natureza_do_cliente  \
# 36   AGROPECUÁRIA            MICRO             PRIVADA
#
#                   instituicao_financeira_credenciada       data_prevista  \
# 36  BANCO REGIONAL DE DESENVOLVIMENTO DO EXTREMO SUL 2006-01-01 23:16:48
#
#     bom_investimento
# 36                 0
